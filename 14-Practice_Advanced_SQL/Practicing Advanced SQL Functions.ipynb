# %% [markdown]
# # Practicing Advanced SQL Functions
#
# ---
#
# ## Imports

# %%
# IMPORTS
import pandas as pd
import numpy as np

# SQL IMPORTS
# import sqlalchemy
import pandas

# ENV IMPORTS
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Load SQL Module

# %%
# %load_ext sql

# %% [markdown]
# ## Connect to Local PostgreSQLDatabase

# %%
user = os.getenv("db_user")
password = os.getenv("db_password")


database = "DVD_Rental"


connection_string = f"postgresql://{user}:{password}@localhost/{database}"
    
# %sql $connection_string

# %% [markdown]
# ## Test Query

# %%
# %%sql
#
# SELECT *
# FROM film
# LIMIT 3;
# Out:
#  * postgresql://postgres:***@localhost/DVD_Rental
# 3 rows affected.
# [(133, 'Chamber Italian', 'A Fateful Reflection of a Moose And a Husband who must Overcome a Monkey in Nigeria', 2006, 1, 7, Decimal('4.99'), 117, Decimal('14.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers'], "'chamber':1 'fate':4 'husband':11 'italian':2 'monkey':16 'moos':8 'must':13 'nigeria':18 'overcom':14 'reflect':5"),
#  (384, 'Grosse Wonderful', 'A Epic Drama of a Cat And a Explorer who must Redeem a Moose in Australia', 2006, 1, 5, Decimal('4.99'), 49, Decimal('19.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Behind the Scenes'], "'australia':18 'cat':8 'drama':5 'epic':4 'explor':11 'gross':1 'moos':16 'must':13 'redeem':14 'wonder':2"),
# ...

# %% [markdown]
# ---
#
# # Practice Window Functions
#
# "A window function performs a calculation across a set of table rows that are somehow related to the current row. This is comparable to the type of calculation that can be done with an aggregate function. But unlike regular aggregate functions, use of a window function does not cause rows to become grouped into a single output row — the rows retain their separate identities. Behind the scenes, the window function is able to access more than just the current row of the query result."
#
# https://mode.com/sql-tutorial/sql-window-functions/

# %% [markdown]
# ### SUM
#
# - We get the SUM total over all the amounts paid.
# - We can choose to PARTITION BY a category like "customer_id"
# - ORDER BY is specified so SQL knows in which order to create the sum totals.
#     - In this case we use "payment_date"

# %%
# %%sql
#
# SELECT c.customer_id,
#         first_name,
#         last_name,
#         payment_id,
#         payment_date,
#         amount,
#         SUM(amount) OVER
#         (PARTITION BY c.customer_id ORDER BY payment_date)
#         AS running_total
# FROM customer c
# JOIN payment p
# ON c.customer_id = p.customer_id
# WHERE c.customer_id < 3;
# Out:
#  * postgresql://postgres:***@localhost/DVD_Rental
# 56 rows affected.
# [(1, 'Mary', 'Smith', 18495, datetime.datetime(2007, 2, 14, 23, 22, 38, 996577), Decimal('5.99'), Decimal('5.99')),
#  (1, 'Mary', 'Smith', 18496, datetime.datetime(2007, 2, 15, 16, 31, 19, 996577), Decimal('0.99'), Decimal('6.98')),
#  (1, 'Mary', 'Smith', 18497, datetime.datetime(2007, 2, 15, 19, 37, 12, 996577), Decimal('9.99'), Decimal('16.97')),
#  (1, 'Mary', 'Smith', 18498, datetime.datetime(2007, 2, 16, 13, 47, 23, 996577), Decimal('4.99'), Decimal('21.96')),
#  (1, 'Mary', 'Smith', 18499, datetime.datetime(2007, 2, 18, 7, 10, 14, 996577), Decimal('4.99'), Decimal('26.95')),
#  (1, 'Mary', 'Smith', 18500, datetime.datetime(2007, 2, 18, 12, 2, 25, 996577), Decimal('0.99'), Decimal('27.94')),
#  (1, 'Mary', 'Smith', 18501, datetime.datetime(2007, 2, 21, 4, 53, 11, 996577), Decimal('3.99'), Decimal('31.93')),
# ...

# %% [markdown]
# ### SUM, AVG, COUNT
#
# - We get the SUM total over all the amounts paid.
# - We can choose to PARTITION BY a category like "customer_id"
# - ORDER BY is specified so SQL knows in which order to create the sum totals.
#     - In this case we use "payment_date"

# %%
# %%sql
#
# SELECT c.customer_id,
#         first_name,
#         last_name,
#         payment_id,
#         payment_date,
#         amount,
#         COUNT(payment_id) OVER
#             (PARTITION BY c.customer_id ORDER BY payment_date)
#             AS running_count,
#         SUM(amount) OVER
#             (PARTITION BY c.customer_id ORDER BY payment_date)
#             AS running_sum,
#         AVG(amount) OVER
#             (PARTITION BY c.customer_id ORDER BY payment_date)
#             AS running_avg
# FROM customer c
# JOIN payment p
# ON c.customer_id = p.customer_id
# WHERE c.customer_id < 3;
# Out:
#  * postgresql://postgres:***@localhost/DVD_Rental
# 56 rows affected.
# [(1, 'Mary', 'Smith', 18495, datetime.datetime(2007, 2, 14, 23, 22, 38, 996577), Decimal('5.99'), 1, Decimal('5.99'), Decimal('5.9900000000000000')),
#  (1, 'Mary', 'Smith', 18496, datetime.datetime(2007, 2, 15, 16, 31, 19, 996577), Decimal('0.99'), 2, Decimal('6.98'), Decimal('3.4900000000000000')),
#  (1, 'Mary', 'Smith', 18497, datetime.datetime(2007, 2, 15, 19, 37, 12, 996577), Decimal('9.99'), 3, Decimal('16.97'), Decimal('5.6566666666666667')),
#  (1, 'Mary', 'Smith', 18498, datetime.datetime(2007, 2, 16, 13, 47, 23, 996577), Decimal('4.99'), 4, Decimal('21.96'), Decimal('5.4900000000000000')),
#  (1, 'Mary', 'Smith', 18499, datetime.datetime(2007, 2, 18, 7, 10, 14, 996577), Decimal('4.99'), 5, Decimal('26.95'), Decimal('5.3900000000000000')),
#  (1, 'Mary', 'Smith', 18500, datetime.datetime(2007, 2, 18, 12, 2, 25, 996577), Decimal('0.99'), 6, Decimal('27.94'), Decimal('4.6566666666666667')),
# ...

# %% [markdown]
# ### ROW NUMBER
#
# "ROW_NUMBER() does just what it sounds like—displays the number of a given row. It starts are 1 and numbers the rows according to the ORDER BY part of the window statement. ROW_NUMBER() does not require you to specify a variable within the parentheses."

# %%
# %%sql
#
# SELECT film_id,
#         title,
#         rating,
#         ROW_NUMBER() OVER
#             (ORDER BY film_id)
#             AS row_number
# FROM film
# WHERE title LIKE '%a';
# Out:
#  * postgresql://postgres:***@localhost/DVD_Rental
# 22 rows affected.
# [(7, 'Airplane Sierra', 'PG-13', 1),
#  (14, 'Alice Fantasia', 'NC-17', 2),
#  (34, 'Arabia Dogma', 'NC-17', 3),
#  (50, 'Baked Cleopatra', 'G', 4),
#  (166, 'Color Philadelphia', 'G', 5),
#  (315, 'Finding Anaconda', 'R', 6),
#  (317, 'Fireball Philadelphia', 'PG', 7),
#  (335, 'Freedom Cleopatra', 'PG-13', 8),
#  (414, 'Hellfighters Sierra', 'PG', 9),
#  (419, 'Hocus Frida', 'G', 10),
#  (462, 'Insider Arizona', 'NC-17', 11),
#  (517, 'Lesson Cleopatra', 'NC-17', 12),
#  (530, 'Lord Arizona', 'PG-13', 13),
#  (572, 'Metropolis Coma', 'PG-13', 14),
#  (627, 'North Tequila', 'NC-17', 15),
#  (657, 'Paradise Sabrina', 'PG-13', 16),
#  (812, 'Smoking Barbarella', 'PG-13', 17),
#  (815, 'Snatchers Montezuma', 'PG-13', 18),
#  (843, 'Steel Santa', 'NC-17', 19),
#  (859, 'Sugar Wonka', 'PG', 20),
#  (968, 'Werewolf Lola', 'G', 21),
#  (986, 'Wonka Sea', 'NC-17', 22)]

# %% [markdown]
# "Using the PARTITION BY clause will allow you to begin counting 1 again in each partition. The following query starts the count over again for each terminal."

# %%
# %%sql
#
# SELECT film_id,
#         title,
#         rating,
#         ROW_NUMBER() OVER
#             (PARTITION BY rating
#              ORDER BY film_id)
#             AS row_number
# FROM film
# WHERE title LIKE '%a';
# Out:
#  * postgresql://postgres:***@localhost/DVD_Rental
# 22 rows affected.
# [(50, 'Baked Cleopatra', 'G', 1),
#  (166, 'Color Philadelphia', 'G', 2),
#  (419, 'Hocus Frida', 'G', 3),
#  (968, 'Werewolf Lola', 'G', 4),
#  (317, 'Fireball Philadelphia', 'PG', 1),
#  (414, 'Hellfighters Sierra', 'PG', 2),
#  (859, 'Sugar Wonka', 'PG', 3),
#  (7, 'Airplane Sierra', 'PG-13', 1),
#  (335, 'Freedom Cleopatra', 'PG-13', 2),
#  (530, 'Lord Arizona', 'PG-13', 3),
#  (572, 'Metropolis Coma', 'PG-13', 4),
#  (657, 'Paradise Sabrina', 'PG-13', 5),
#  (812, 'Smoking Barbarella', 'PG-13', 6),
#  (815, 'Snatchers Montezuma', 'PG-13', 7),
#  (315, 'Finding Anaconda', 'R', 1),
#  (14, 'Alice Fantasia', 'NC-17', 1),
#  (34, 'Arabia Dogma', 'NC-17', 2),
#  (462, 'Insider Arizona', 'NC-17', 3),
#  (517, 'Lesson Cleopatra', 'NC-17', 4),
#  (627, 'North Tequila', 'NC-17', 5),
#  (843, 'Steel Santa', 'NC-17', 6),
#  (986, 'Wonka Sea', 'NC-17', 7)]

# %% [markdown]
# ### RANK
#
# "RANK() is slightly different from ROW_NUMBER(). If you order by start_time, for example, it might be the case that some terminals have rides with two identical start times. In this case, they are given the same rank, whereas ROW_NUMBER() gives them different numbers. In the following query, you notice the 4th and 5th observations for start_terminal 31000—they are both given a rank of 4, and the following result receives a rank of 6."

# %%
# %%sql
#
# SELECT film_id,
#         title,
#         rating,
#         length,
#         RANK() OVER
#             (PARTITION BY rating
#              ORDER BY length)
#             AS rank
# FROM film
# WHERE title LIKE '%y';
# Out:
#  * postgresql://postgres:***@localhost/DVD_Rental
# 70 rows affected.
# [(226, 'Destiny Saturday', 'G', 56, 1),
#  (891, 'Timberland Sky', 'G', 69, 2),
#  (154, 'Clash Freddy', 'G', 81, 3),
#  (26, 'Annie Identity', 'G', 86, 4),
#  (702, 'Pulp Beverly', 'G', 89, 5),
#  (915, 'Truman Crazy', 'G', 92, 6),
#  (366, 'Goldfinger Sensibility', 'G', 93, 7),
#  (478, 'Jaws Harry', 'G', 112, 8),
#  (239, 'Dogma Family', 'G', 122, 9),
#  (80, 'Blanket Beverly', 'G', 148, 10),
#  (376, 'Grapes Fury', 'G', 155, 11),
#  (622, 'Newsies Story', 'G', 159, 12),
#  (485, 'Jersey Sassy', 'PG', 60, 1),
#  (274, 'Egg Igby', 'PG', 67, 2),
#  (963, 'Watch Tracy', 'PG', 78, 3),
#  (336, 'French Holiday', 'PG', 99, 4),
#  (65, 'Behavior Runaway', 'PG', 100, 5),
#  (19, 'Amadeus Holy', 'PG', 113, 6),
#  (515, 'Legally Secretary', 'PG', 113, 6),
#  (201, 'Cyclone Family', 'PG', 176, 8),
#  (630, 'Notting Speakeasy', 'PG-13', 48, 1),
#  (489, 'Juggler Hardly', 'PG-13', 54, 2),
# ...

# %% [markdown]
# ### DENSE RANK
#
# You can also use DENSE_RANK() instead of RANK() depending on your application. Imagine a situation in which three entries have the same value. Using either command, they will all get the same rank. For the sake of this example, let's say it's "2." Here's how the two commands would evaluate the next results differently.
#
# RANK() would give the identical rows a rank of 2, then skip ranks 3 and 4, so the next result would be 5
# DENSE_RANK() would still give all the identical rows a rank of 2, but the following row would be 3—no ranks would be skipped.

# %%
# %%sql
#
# SELECT film_id,
#         title,
#         rating,
#         length,
#         DENSE_RANK() OVER
#             (PARTITION BY rating
#              ORDER BY length)
#             AS dense_rank
# FROM film
# WHERE title LIKE '%y';
# Out:
#  * postgresql://postgres:***@localhost/DVD_Rental
# 70 rows affected.
# [(226, 'Destiny Saturday', 'G', 56, 1),
#  (891, 'Timberland Sky', 'G', 69, 2),
#  (154, 'Clash Freddy', 'G', 81, 3),
#  (26, 'Annie Identity', 'G', 86, 4),
#  (702, 'Pulp Beverly', 'G', 89, 5),
#  (915, 'Truman Crazy', 'G', 92, 6),
#  (366, 'Goldfinger Sensibility', 'G', 93, 7),
#  (478, 'Jaws Harry', 'G', 112, 8),
#  (239, 'Dogma Family', 'G', 122, 9),
#  (80, 'Blanket Beverly', 'G', 148, 10),
#  (376, 'Grapes Fury', 'G', 155, 11),
#  (622, 'Newsies Story', 'G', 159, 12),
#  (485, 'Jersey Sassy', 'PG', 60, 1),
#  (274, 'Egg Igby', 'PG', 67, 2),
#  (963, 'Watch Tracy', 'PG', 78, 3),
#  (336, 'French Holiday', 'PG', 99, 4),
#  (65, 'Behavior Runaway', 'PG', 100, 5),
#  (19, 'Amadeus Holy', 'PG', 113, 6),
#  (515, 'Legally Secretary', 'PG', 113, 6),
#  (201, 'Cyclone Family', 'PG', 176, 7),
#  (630, 'Notting Speakeasy', 'PG-13', 48, 1),
#  (489, 'Juggler Hardly', 'PG-13', 54, 2),
# ...

# %% [markdown]
# ### NTILE
#
# You can use window functions to identify what percentile (or quartile, or any other subdivision) a given row falls into. The syntax is NTILE(*# of buckets*). In this case, ORDER BY determines which column to use to determine the quartiles (or whatever number of 'tiles you specify).

# %%
# %%sql
#
# SELECT film_id,
#         title,
#         rating,
#         length,
#         NTILE(4) OVER
#          (PARTITION BY rating
#           ORDER BY length)
#           AS quartile,
#         NTILE(5) OVER
#          (PARTITION BY rating
#           ORDER BY length)
#           AS quintile,
#         NTILE(100) OVER
#          (PARTITION BY rating
#           ORDER BY length)
#           AS percentile
# FROM film
# WHERE title LIKE '%y';
# Out:
#  * postgresql://postgres:***@localhost/DVD_Rental
# 70 rows affected.
# [(226, 'Destiny Saturday', 'G', 56, 1, 1, 1),
#  (891, 'Timberland Sky', 'G', 69, 1, 1, 2),
#  (154, 'Clash Freddy', 'G', 81, 1, 1, 3),
#  (26, 'Annie Identity', 'G', 86, 2, 2, 4),
#  (702, 'Pulp Beverly', 'G', 89, 2, 2, 5),
#  (915, 'Truman Crazy', 'G', 92, 2, 2, 6),
#  (366, 'Goldfinger Sensibility', 'G', 93, 3, 3, 7),
#  (478, 'Jaws Harry', 'G', 112, 3, 3, 8),
#  (239, 'Dogma Family', 'G', 122, 3, 4, 9),
#  (80, 'Blanket Beverly', 'G', 148, 4, 4, 10),
#  (376, 'Grapes Fury', 'G', 155, 4, 5, 11),
#  (622, 'Newsies Story', 'G', 159, 4, 5, 12),
#  (485, 'Jersey Sassy', 'PG', 60, 1, 1, 1),
#  (274, 'Egg Igby', 'PG', 67, 1, 1, 2),
#  (963, 'Watch Tracy', 'PG', 78, 2, 2, 3),
#  (336, 'French Holiday', 'PG', 99, 2, 2, 4),
#  (65, 'Behavior Runaway', 'PG', 100, 3, 3, 5),
#  (19, 'Amadeus Holy', 'PG', 113, 3, 3, 6),
#  (515, 'Legally Secretary', 'PG', 113, 4, 4, 7),
#  (201, 'Cyclone Family', 'PG', 176, 4, 5, 8),
# ...

# %%
# %%sql
#
# SELECT film_id,
#         title,
#         rating,
#         length,
#         NTILE(4) OVER
#          (ORDER BY length)
#           AS quartile,
#         NTILE(5) OVER
#          (ORDER BY length)
#           AS quintile,
#         NTILE(100) OVER
#          (ORDER BY length)
#           AS percentile
# FROM film
# WHERE rating = 'G';
# Out:
#  * postgresql://postgres:***@localhost/DVD_Rental
# 178 rows affected.
# [(247, 'Downhill Enough', 'G', 47, 1, 1, 1),
#  (237, 'Divorce Shining', 'G', 47, 1, 1, 1),
#  (575, 'Midsummer Groundhog', 'G', 48, 1, 1, 2),
#  (2, 'Ace Goldfinger', 'G', 48, 1, 1, 2),
#  (430, 'Hook Chariots', 'G', 49, 1, 1, 3),
#  (83, 'Blues Instinct', 'G', 50, 1, 1, 3),
#  (292, 'Excitement Eve', 'G', 51, 1, 1, 4),
#  (542, 'Lust Lock', 'G', 52, 1, 1, 4),
#  (402, 'Harper Dying', 'G', 52, 1, 1, 5),
#  (794, 'Side Ark', 'G', 52, 1, 1, 5),
#  (862, 'Summer Scarface', 'G', 53, 1, 1, 6),
#  (697, 'Primary Glass', 'G', 53, 1, 1, 6),
#  (497, 'Kill Brotherhood', 'G', 54, 1, 1, 7),
#  (226, 'Destiny Saturday', 'G', 56, 1, 1, 7),
#  (97, 'Bride Intrigue', 'G', 56, 1, 1, 8),
#  (598, 'Mosquito Armageddon', 'G', 57, 1, 1, 8),
#  (238, 'Doctor Grail', 'G', 57, 1, 1, 9),
#  (626, 'Noon Papi', 'G', 57, 1, 1, 9),
#  (732, 'Rings Heartbreakers', 'G', 58, 1, 1, 10),
#  (409, 'Heartbreakers Bright', 'G', 59, 1, 1, 10),
# ...

# %% [markdown]
# ### LAG and LEAD
#
# "It can often be useful to compare rows to preceding or following rows, especially if you've got the data in an order that makes sense. You can use LAG or LEAD to create columns that pull values from other rows—all you need to do is enter which column to pull from and how many rows away you'd like to do the pull. LAG pulls from previous rows and LEAD pulls from following rows."

# %%
# %%sql
#
# SELECT film_id,
#         title,
#         rating,
#         length,
#         LAG(length, 1) OVER
#             (PARTITION BY rating ORDER BY length)
#             AS "lag_(previous_row_length)"
# FROM film
# WHERE title LIKE '%y';
# Out:
#  * postgresql://postgres:***@localhost/DVD_Rental
# 70 rows affected.
# [(226, 'Destiny Saturday', 'G', 56, None),
#  (891, 'Timberland Sky', 'G', 69, 56),
#  (154, 'Clash Freddy', 'G', 81, 69),
#  (26, 'Annie Identity', 'G', 86, 81),
#  (702, 'Pulp Beverly', 'G', 89, 86),
#  (915, 'Truman Crazy', 'G', 92, 89),
#  (366, 'Goldfinger Sensibility', 'G', 93, 92),
#  (478, 'Jaws Harry', 'G', 112, 93),
#  (239, 'Dogma Family', 'G', 122, 112),
#  (80, 'Blanket Beverly', 'G', 148, 122),
#  (376, 'Grapes Fury', 'G', 155, 148),
#  (622, 'Newsies Story', 'G', 159, 155),
#  (485, 'Jersey Sassy', 'PG', 60, None),
#  (274, 'Egg Igby', 'PG', 67, 60),
#  (963, 'Watch Tracy', 'PG', 78, 67),
#  (336, 'French Holiday', 'PG', 99, 78),
#  (65, 'Behavior Runaway', 'PG', 100, 99),
#  (19, 'Amadeus Holy', 'PG', 113, 100),
#  (515, 'Legally Secretary', 'PG', 113, 113),
#  (201, 'Cyclone Family', 'PG', 176, 113),
#  (630, 'Notting Speakeasy', 'PG-13', 48, None),
#  (489, 'Juggler Hardly', 'PG-13', 54, 48),
# ...

# %%
# %%sql
#
# SELECT film_id,
#         title,
#         rating,
#         length,
#         LEAD(length, 1) OVER
#             (PARTITION BY rating ORDER BY length)
#             AS "Lead_(next_row_length)"
# FROM film
# WHERE title LIKE '%y';
# Out:
#  * postgresql://postgres:***@localhost/DVD_Rental
# 70 rows affected.
# [(226, 'Destiny Saturday', 'G', 56, 69),
#  (891, 'Timberland Sky', 'G', 69, 81),
#  (154, 'Clash Freddy', 'G', 81, 86),
#  (26, 'Annie Identity', 'G', 86, 89),
#  (702, 'Pulp Beverly', 'G', 89, 92),
#  (915, 'Truman Crazy', 'G', 92, 93),
#  (366, 'Goldfinger Sensibility', 'G', 93, 112),
#  (478, 'Jaws Harry', 'G', 112, 122),
#  (239, 'Dogma Family', 'G', 122, 148),
#  (80, 'Blanket Beverly', 'G', 148, 155),
#  (376, 'Grapes Fury', 'G', 155, 159),
#  (622, 'Newsies Story', 'G', 159, None),
#  (485, 'Jersey Sassy', 'PG', 60, 67),
#  (274, 'Egg Igby', 'PG', 67, 78),
#  (963, 'Watch Tracy', 'PG', 78, 99),
#  (336, 'French Holiday', 'PG', 99, 100),
#  (65, 'Behavior Runaway', 'PG', 100, 113),
#  (19, 'Amadeus Holy', 'PG', 113, 113),
#  (515, 'Legally Secretary', 'PG', 113, 176),
#  (201, 'Cyclone Family', 'PG', 176, None),
#  (630, 'Notting Speakeasy', 'PG-13', 48, 54),
#  (489, 'Juggler Hardly', 'PG-13', 54, 57),
# ...

# %% [markdown]
# **"Lag and Lead are especially useful if you want to calculate differences between rows."**

# %%
# %%sql
#
# SELECT film_id,
#         title,
#         rating,
#         length,
#         length -LAG(length, 1) OVER
#             (PARTITION BY rating ORDER BY length)
#             AS difference
# FROM film
# WHERE title LIKE '%y';
# Out:
#  * postgresql://postgres:***@localhost/DVD_Rental
# 70 rows affected.
# [(226, 'Destiny Saturday', 'G', 56, None),
#  (891, 'Timberland Sky', 'G', 69, 13),
#  (154, 'Clash Freddy', 'G', 81, 12),
#  (26, 'Annie Identity', 'G', 86, 5),
#  (702, 'Pulp Beverly', 'G', 89, 3),
#  (915, 'Truman Crazy', 'G', 92, 3),
#  (366, 'Goldfinger Sensibility', 'G', 93, 1),
#  (478, 'Jaws Harry', 'G', 112, 19),
#  (239, 'Dogma Family', 'G', 122, 10),
#  (80, 'Blanket Beverly', 'G', 148, 26),
#  (376, 'Grapes Fury', 'G', 155, 7),
#  (622, 'Newsies Story', 'G', 159, 4),
#  (485, 'Jersey Sassy', 'PG', 60, None),
#  (274, 'Egg Igby', 'PG', 67, 7),
#  (963, 'Watch Tracy', 'PG', 78, 11),
#  (336, 'French Holiday', 'PG', 99, 21),
#  (65, 'Behavior Runaway', 'PG', 100, 1),
#  (19, 'Amadeus Holy', 'PG', 113, 13),
#  (515, 'Legally Secretary', 'PG', 113, 0),
#  (201, 'Cyclone Family', 'PG', 176, 63),
#  (630, 'Notting Speakeasy', 'PG-13', 48, None),
#  (489, 'Juggler Hardly', 'PG-13', 54, 6),
# ...

# %% [markdown]
# **"The first row of the difference column is null because there is no previous row from which to pull. Similarly, using LEAD will create nulls at the end of the dataset. If you'd like to make the results a bit cleaner, you can wrap it in an outer query to remove nulls."**

# %%
# %%sql
#
# SELECT *
# FROM (
#     SELECT film_id,
#             title,
#             rating,
#             length,
#             length -LAG(length, 1) OVER
#                 (PARTITION BY rating ORDER BY length)
#                 AS difference
#     FROM film
#     WHERE title LIKE '%y'
#     ) sub
# WHERE sub.difference IS NOT NULL;
# Out:
#  * postgresql://postgres:***@localhost/DVD_Rental
# 65 rows affected.
# [(891, 'Timberland Sky', 'G', 69, 13),
#  (154, 'Clash Freddy', 'G', 81, 12),
#  (26, 'Annie Identity', 'G', 86, 5),
#  (702, 'Pulp Beverly', 'G', 89, 3),
#  (915, 'Truman Crazy', 'G', 92, 3),
#  (366, 'Goldfinger Sensibility', 'G', 93, 1),
#  (478, 'Jaws Harry', 'G', 112, 19),
#  (239, 'Dogma Family', 'G', 122, 10),
#  (80, 'Blanket Beverly', 'G', 148, 26),
#  (376, 'Grapes Fury', 'G', 155, 7),
#  (622, 'Newsies Story', 'G', 159, 4),
#  (274, 'Egg Igby', 'PG', 67, 7),
#  (963, 'Watch Tracy', 'PG', 78, 11),
#  (336, 'French Holiday', 'PG', 99, 21),
#  (65, 'Behavior Runaway', 'PG', 100, 1),
#  (19, 'Amadeus Holy', 'PG', 113, 13),
#  (515, 'Legally Secretary', 'PG', 113, 0),
#  (201, 'Cyclone Family', 'PG', 176, 63),
#  (489, 'Juggler Hardly', 'PG-13', 54, 6),
#  (18, 'Alter Victory', 'PG-13', 57, 3),
#  (940, 'Victory Academy', 'PG-13', 64, 7),
#  (790, 'Shootist Superfly', 'PG-13', 67, 3),
# ...

# %% [markdown]
# ### Defining a window alias
#
# "If you're planning to write several window functions in to the same query, using the same window, you can create an alias. Take the NTILE example above."
#
# **The WINDOW clause, if included, should always come after the WHERE clause.**

# %%
# %%sql
#
# SELECT film_id,
#         title,
#         rating,
#         length,
#         NTILE(4) OVER ntile_window AS quartile,
#         NTILE(5) OVER ntile_window AS quintile,
#         NTILE(100) OVER ntile_window AS percentile
# FROM film
# WHERE title LIKE '%y'
# WINDOW ntile_window
#     AS (PARTITION BY rating ORDER BY length);
# Out:
#  * postgresql://postgres:***@localhost/DVD_Rental
# 70 rows affected.
# [(226, 'Destiny Saturday', 'G', 56, 1, 1, 1),
#  (891, 'Timberland Sky', 'G', 69, 1, 1, 2),
#  (154, 'Clash Freddy', 'G', 81, 1, 1, 3),
#  (26, 'Annie Identity', 'G', 86, 2, 2, 4),
#  (702, 'Pulp Beverly', 'G', 89, 2, 2, 5),
#  (915, 'Truman Crazy', 'G', 92, 2, 2, 6),
#  (366, 'Goldfinger Sensibility', 'G', 93, 3, 3, 7),
#  (478, 'Jaws Harry', 'G', 112, 3, 3, 8),
#  (239, 'Dogma Family', 'G', 122, 3, 4, 9),
#  (80, 'Blanket Beverly', 'G', 148, 4, 4, 10),
#  (376, 'Grapes Fury', 'G', 155, 4, 5, 11),
#  (622, 'Newsies Story', 'G', 159, 4, 5, 12),
#  (485, 'Jersey Sassy', 'PG', 60, 1, 1, 1),
#  (274, 'Egg Igby', 'PG', 67, 1, 1, 2),
#  (963, 'Watch Tracy', 'PG', 78, 2, 2, 3),
#  (336, 'French Holiday', 'PG', 99, 2, 2, 4),
#  (65, 'Behavior Runaway', 'PG', 100, 3, 3, 5),
#  (19, 'Amadeus Holy', 'PG', 113, 3, 3, 6),
#  (515, 'Legally Secretary', 'PG', 113, 4, 4, 7),
#  (201, 'Cyclone Family', 'PG', 176, 4, 5, 8),
# ...

# %% [markdown]
# ###  Max
#
# MAX works in the same way as SUM

# %%
# %%sql
#
# SELECT film_id,
#         title,
#         rating,
#         length,
#         MAX(length) OVER
#             (PARTITION BY rating
#              ORDER BY film_id)
#             AS max
# FROM film
# WHERE title LIKE '%y';
# Out:
#  * postgresql://postgres:***@localhost/DVD_Rental
# 70 rows affected.
# [(26, 'Annie Identity', 'G', 86, 86),
#  (80, 'Blanket Beverly', 'G', 148, 148),
#  (154, 'Clash Freddy', 'G', 81, 148),
#  (226, 'Destiny Saturday', 'G', 56, 148),
#  (239, 'Dogma Family', 'G', 122, 148),
#  (366, 'Goldfinger Sensibility', 'G', 93, 148),
#  (376, 'Grapes Fury', 'G', 155, 155),
#  (478, 'Jaws Harry', 'G', 112, 155),
#  (622, 'Newsies Story', 'G', 159, 159),
#  (702, 'Pulp Beverly', 'G', 89, 159),
#  (891, 'Timberland Sky', 'G', 69, 159),
#  (915, 'Truman Crazy', 'G', 92, 159),
#  (19, 'Amadeus Holy', 'PG', 113, 113),
#  (65, 'Behavior Runaway', 'PG', 100, 113),
#  (201, 'Cyclone Family', 'PG', 176, 176),
#  (274, 'Egg Igby', 'PG', 67, 176),
#  (336, 'French Holiday', 'PG', 99, 176),
#  (485, 'Jersey Sassy', 'PG', 60, 176),
#  (515, 'Legally Secretary', 'PG', 113, 176),
#  (963, 'Watch Tracy', 'PG', 78, 176),
#  (18, 'Alter Victory', 'PG-13', 57, 57),
#  (57, 'Basic Easy', 'PG-13', 90, 90),
# ...

# %% [markdown]
# (Below)
#
# **"After we specify the field to order by, we add a definition for our window size: ROWS BETWEEN 3 PRECEDING AND 1 PRECEDING. This clause is essentially saying, "look back across the previous 3 films (not including the current order) and take the maximum value.""**

# %%
# %%sql
#
# SELECT film_id,
#         title,
#         rating,
#         length,
#         MAX(length) OVER
#             (PARTITION BY rating
#              ORDER BY film_id
#              ROWS BETWEEN 3 PRECEDING AND 1 PRECEDING)
#             AS max
# FROM film
# WHERE title LIKE '%y';
# Out:
#  * postgresql://postgres:***@localhost/DVD_Rental
# 70 rows affected.
# [(26, 'Annie Identity', 'G', 86, None),
#  (80, 'Blanket Beverly', 'G', 148, 86),
#  (154, 'Clash Freddy', 'G', 81, 148),
#  (226, 'Destiny Saturday', 'G', 56, 148),
#  (239, 'Dogma Family', 'G', 122, 148),
#  (366, 'Goldfinger Sensibility', 'G', 93, 122),
#  (376, 'Grapes Fury', 'G', 155, 122),
#  (478, 'Jaws Harry', 'G', 112, 155),
#  (622, 'Newsies Story', 'G', 159, 155),
#  (702, 'Pulp Beverly', 'G', 89, 159),
#  (891, 'Timberland Sky', 'G', 69, 159),
#  (915, 'Truman Crazy', 'G', 92, 159),
#  (19, 'Amadeus Holy', 'PG', 113, None),
#  (65, 'Behavior Runaway', 'PG', 100, 113),
#  (201, 'Cyclone Family', 'PG', 176, 113),
#  (274, 'Egg Igby', 'PG', 67, 176),
#  (336, 'French Holiday', 'PG', 99, 176),
#  (485, 'Jersey Sassy', 'PG', 60, 176),
#  (515, 'Legally Secretary', 'PG', 113, 99),
#  (963, 'Watch Tracy', 'PG', 78, 113),
#  (18, 'Alter Victory', 'PG-13', 57, None),
#  (57, 'Basic Easy', 'PG-13', 90, 57),
# ...

# %% [markdown]
# ---
# ---
#
# # Common Table Expressions
#
#
# "In PostgreSQL, the CTE(Common Table Expression) is used as a temporary result set that the user can reference within another SQL statement like SELECT, INSERT, UPDATE or DELETE. CTEs are temporary in the sense that they only exist during the execution of the query. CTEs are typically used to simplify complex joins and subqueries in PostgreSQL."
#
# https://www.geeksforgeeks.org/postgresql-cte/
#
#
# - Let’s analyze the below syntax.
#
# - The first step is to set the name of the CTE followed by an optional column list.
#
# - Then we specify a query that returns the result set within the body of WITH clause.
#
#     - If not specified explicitly, then the select list of the CTE_query_definition will become the column list of the CTE.
#
# - Finally use the CTE like a table or view in the statement which can be a SELECT, INSERT, UPDATE, or DELETE.

# %%
# %%sql
#
# WITH cte_film AS (
#     SELECT film_id,
#             title,
#             length,
#             length > 120 AS over2hrs
#     FROM film
# )
# SELECT film_id,
#         title,
#         length
# FROM cte_film
# WHERE over2hrs = TRUE
# ORDER BY 1;
# Out:
#  * postgresql://postgres:***@localhost/DVD_Rental
# 457 rows affected.
# [(5, 'African Egg', 130),
#  (6, 'Agent Truman', 169),
#  (11, 'Alamo Videotape', 126),
#  (12, 'Alaska Phantom', 136),
#  (13, 'Ali Forever', 150),
#  (16, 'Alley Evolution', 180),
#  (21, 'American Circus', 129),
#  (24, 'Analyze Hoosiers', 181),
#  (27, 'Anonymous Human', 179),
#  (29, 'Antitrust Tomatoes', 168),
#  (33, 'Apollo Teen', 153),
#  (35, 'Arachnophobia Rollercoaster', 147),
#  (36, 'Argonauts Town', 127),
#  (37, 'Arizona Bang', 121),
#  (40, 'Army Flintstones', 148),
#  (41, 'Arsenic Independence', 137),
#  (42, 'Artist Coldblooded', 170),
#  (43, 'Atlantis Cause', 170),
#  (47, 'Baby Hall', 153),
#  (49, 'Badman Dawn', 162),
#  (50, 'Baked Cleopatra', 182),
#  (52, 'Ballroom Mockingbird', 173),
#  (56, 'Barefoot Manchurian', 129),
#  (58, 'Beach Heartbreakers', 122),
#  (59, 'Bear Graceland', 160),
#  (61, 'Beauty Grease', 175),
#  (64, 'Beethoven Exorcist', 151),
#  (68, 'Betrayed Rear', 122),
# ...

# %% [markdown]
# ### CTE with case when

# %%
# %%sql
#
# WITH cte_film AS (
#     SELECT film_id,
#             title,
#             (CASE
#                 WHEN length < 90 THEN 'Short'
#                 WHEN length < 120 THEN 'Medium'
#                 ELSE 'Long'
#             END) AS length
#     FROM film
# )
# SELECT film_id,
#         title,
#         length
# FROM cte_film
# WHERE length = 'Short'
# ORDER BY 1;
# Out:
#  * postgresql://postgres:***@localhost/DVD_Rental
# 320 rows affected.
# [(1, 'Academy Dinosaur', 'Short'),
#  (2, 'Ace Goldfinger', 'Short'),
#  (3, 'Adaptation Holes', 'Short'),
#  (7, 'Airplane Sierra', 'Short'),
#  (8, 'Airport Pollock', 'Short'),
#  (10, 'Aladdin Calendar', 'Short'),
#  (15, 'Alien Center', 'Short'),
#  (17, 'Alone Trip', 'Short'),
#  (18, 'Alter Victory', 'Short'),
#  (20, 'Amelie Hellfighters', 'Short'),
#  (22, 'Amistad Midsummer', 'Short'),
#  (25, 'Angels Life', 'Short'),
#  (26, 'Annie Identity', 'Short'),
#  (30, 'Anything Savannah', 'Short'),
#  (34, 'Arabia Dogma', 'Short'),
#  (38, 'Ark Ridgemont', 'Short'),
#  (45, 'Attraction Newton', 'Short'),
#  (51, 'Balloon Homeward', 'Short'),
#  (53, 'Bang Kwai', 'Short'),
#  (55, 'Barbarella Streetcar', 'Short'),
#  (60, 'Beast Hunchback', 'Short'),
#  (63, 'Bedazzled Married', 'Short'),
#  (66, 'Beneath Rush', 'Short'),
#  (67, 'Berets Agent', 'Short'),
#  (69, 'Beverly Outlaw', 'Short'),
# ...

# %% [markdown]
# ### CTE with Window Functions
#
# Finding the 2nd longest films in each age rating category using DENSE_RANK().

# %%
# %%sql
#
# WITH cte_film AS  (
#     SELECT film_id,
#             title,
#             rating,
#             length,
#             DENSE_RANK() OVER (
#                 PARTITION BY rating
#                 ORDER BY length DESC)
#             AS length_rank
#     FROM film
# )
# SELECT *
# FROM cte_film
# WHERE length_rank = 2;
# Out:
#  * postgresql://postgres:***@localhost/DVD_Rental
# 8 rows affected.
# [(597, 'Moonwalker Fool', 'G', 184, 2),
#  (719, 'Records Zorro', 'PG', 182, 2),
#  (591, 'Monsoon Cause', 'PG', 182, 2),
#  (180, 'Conspiracy Spirit', 'PG-13', 184, 2),
#  (886, 'Theory Mermaid', 'PG-13', 184, 2),
#  (813, 'Smoochy Control', 'R', 184, 2),
#  (767, 'Scalawag Duck', 'NC-17', 183, 2),
#  (973, 'Wife Turn', 'NC-17', 183, 2)]
